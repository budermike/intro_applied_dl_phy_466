# %% [markdown]
# <a href="https://colab.research.google.com/github/budermike/intro_applied_dl_phy_466/blob/master/CNN_exam_mike_buder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Galaxy Classification, Anomaly Detection, Autoencoder & VAE (Keras)
# This notebook uses the Galaxy10 DECaLS dataset (astronomical galaxy images) for:
#
# 1. Data loading & splitting, defining an anomaly class
# 2. CNN classifier + ROC curves & confusion matrices
# 3. Convolutional autoencoder for anomaly detection
# 4. Variational autoencoder (VAE) + galaxy generation
#
# Dataset: Galaxy10 DECaLS (HDF5).

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"
import tensorflow as tf
import keras
from keras import layers, ops, Model, random, models

import numpy as np
import h5py
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc, confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## 1. Download the dataset, inspect classes, create anomaly split
#
# Steps:
# - Download `Galaxy10_DECals_64.h5`
# - Load images and labels with `h5py`
# - Inspect shape and class distribution
# - Remove class 4 and store it as the anomaly dataset
# - Split remaining (standard) data into train (50%), val (25%), test (25%)

# %%
# Download Galaxy10 DECaLS (HDF5)
! rm ./Galaxy10_DECals_64.h5
! wget https://cernbox.cern.ch/remote.php/dav/public-files/RyWK8CBk2yqKR0b/Galaxy10_DECals_64.h5
data_path = "./Galaxy10_DECals_64.h5"

print("Downloaded to:", data_path)

# %%
# Copy data onto drive s.t. dont need to download every time
from google.colab import drive
drive.mount('/content/drive')

import os
from pathlib import Path

# Pfade
drive_path = Path("/content/drive/MyDrive/Galaxy10_DECals_64.h5")
local_path = Path("./Galaxy10_DECals_64.h5")

#!cp "./Galaxy10_DECals_64.h5" "/content/drive/MyDrive/Galaxy10_DECals_64.h5"

# 1. case: data not on google drive
if not drive_path.exists():
    print("start download from cern...")
    # !wget -O "{drive_path}" https://cernbox.cern.ch/remote.php/dav/public-files/RyWK8CBk2yqKR0b/Galaxy10_DECals_64.h5
    print("finished download from cern!")
else:
    print("dataset already on google drive")

# 2. case: data on google drive
if not local_path.exists():
    print("copy data from google drive into colab")
    # !cp "{drive_path}" "{local_path}"
else:
    print("data already in colab")

# Endgültiger Pfad für den Rest deines Codes
data_path = "./Galaxy10_DECals_64.h5"
print(f"Data path: {data_path}")
# Out:
# Mounted at /content/drive
# dataset already on google drive
# copy data from google drive into colab
# Data path: ./Galaxy10_DECals_64.h5

# %%
# Load images and labels using h5py
with h5py.File(data_path, "r") as f:
    images = np.array(f["images"])   # shape (17736, 256, 256, 3)
    labels = np.array(f["ans"])      # shape (17736,)

#  normalize pixels in [0,1]
images = images/255

print("Images shape:", images.shape)
print("Labels shape:", labels.shape, "dtype:", labels.dtype)
# Out:
# Images shape: (17736, 64, 64, 3)
# Labels shape: (17736,) dtype: uint8

# %%
# Class names from the Galaxy10 DECaLS documentation
class_names = {
    0: "Disturbed Galaxies",
    1: "Merging Galaxies",
    2: "Round Smooth Galaxies",
    3: "In-between Round Smooth Galaxies",
    4: "Cigar Shaped Smooth Galaxies",  # will be 'anomaly'
    5: "Barred Spiral Galaxies",
    6: "Unbarred Tight Spiral Galaxies",
    7: "Unbarred Loose Spiral Galaxies",
    8: "Edge-on Galaxies without Bulge",
    9: "Edge-on Galaxies with Bulge"
}

unique, counts = np.unique(labels, return_counts=True)
print("Class distribution:")
for u, c in zip(unique, counts):
    print(f"Class {u} ({class_names[u]}): {c}")
# Out:
# Class distribution:
# Class 0 (Disturbed Galaxies): 1081
# Class 1 (Merging Galaxies): 1853
# Class 2 (Round Smooth Galaxies): 2645
# Class 3 (In-between Round Smooth Galaxies): 2027
# Class 4 (Cigar Shaped Smooth Galaxies): 334
# Class 5 (Barred Spiral Galaxies): 2043
# Class 6 (Unbarred Tight Spiral Galaxies): 1829
# Class 7 (Unbarred Loose Spiral Galaxies): 2628
# Class 8 (Edge-on Galaxies without Bulge): 1423
# Class 9 (Edge-on Galaxies with Bulge): 1873

# %%
# Show a grid of sample images from different classes
def show_examples(images, labels, class_names, n_rows=4, n_cols=6):
    plt.figure(figsize=(3*n_cols, 3*n_rows))
    indices = np.random.choice(len(images), size=n_rows*n_cols, replace=False)
    for i, idx in enumerate(indices):
        plt.subplot(n_rows, n_cols, i+1)
        plt.imshow(images[idx])
        plt.title(f"Class {labels[idx]}:\n{class_names[int(labels[idx])]}", fontsize=8)
        plt.axis("off")
    plt.tight_layout()
    plt.show()

show_examples(images, labels, class_names)

# %%
# Create anomaly dataset: all class 0 images
ANOMALY_CLASS = 0

anomaly_mask = (labels == ANOMALY_CLASS)
standard_mask = ~anomaly_mask

anom_images = images[anomaly_mask]
anom_labels = labels[anomaly_mask]  # all 0, but we keep them for bookkeeping

std_images = images[standard_mask]
std_labels_original = labels[standard_mask]

print("Standard images:", std_images.shape)
print("Anomaly images:", anom_images.shape)
# Out:
# Standard images: (16655, 64, 64, 3)
# Anomaly images: (1081, 64, 64, 3)

# %%
# For training, remap standard labels from {0,1,2,3,5,6,7,8,9} -> {0,...,8}
unique_std_classes = sorted(np.unique(std_labels_original))
print("Standard classes (original indices):", unique_std_classes)

# Create mapping dict
label_map = {original: new for new, original in enumerate(unique_std_classes)}
inv_label_map = {v: k for k, v in label_map.items()}

print("Label map (original -> new):", label_map)

std_labels = np.vectorize(label_map.get)(std_labels_original)
print("Remapped standard labels min/max:", std_labels.min(), std_labels.max())
n_classes = len(unique_std_classes)
# Out:
# Standard classes (original indices): [np.uint8(1), np.uint8(2), np.uint8(3), np.uint8(4), np.uint8(5), np.uint8(6), np.uint8(7), np.uint8(8), np.uint8(9)]
# Label map (original -> new): {np.uint8(1): 0, np.uint8(2): 1, np.uint8(3): 2, np.uint8(4): 3, np.uint8(5): 4, np.uint8(6): 5, np.uint8(7): 6, np.uint8(8): 7, np.uint8(9): 8}
# Remapped standard labels min/max: 0 8

# %%
# Split standard data: 50% train, 25% val, 25% test

# First split: train (50%) and temp (50%)
X_train_std, X_temp_std, y_train_std, y_temp_std = train_test_split(
    std_images,
    std_labels,
    test_size=0.5,
    stratify=std_labels,
    random_state=42
)

# Second split: temp into val (25%) and test (25%) of full standard data
X_val_std, X_test_std, y_val_std, y_test_std = train_test_split(
    X_temp_std,
    y_temp_std,
    test_size=0.5,
    stratify=y_temp_std,
    random_state=42
)

print("Train standard:", X_train_std.shape, y_train_std.shape)
print("Val standard:  ", X_val_std.shape, y_val_std.shape)
print("Test standard: ", X_test_std.shape, y_test_std.shape)
del std_images, std_labels, X_temp_std, y_temp_std
# Out:
# Train standard: (8327, 64, 64, 3) (8327,)
# Val standard:   (4164, 64, 64, 3) (4164,)
# Test standard:  (4164, 64, 64, 3) (4164,)

# %%
# Plot training history (accuracy and loss)
def plot_training_history(history):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

    # Plot accuracy
    ax1.plot(history.history['accuracy'], label='Training Accuracy')
    ax1.plot(history.history['val_accuracy'], label='Validation Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.set_title('Training and Validation Accuracy')
    ax1.legend()

    # Plot loss
    ax2.plot(history.history['loss'], label='Training Loss')
    ax2.plot(history.history['val_loss'], label='Validation Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.set_title('Training and Validation Loss')
    ax2.legend()

    plt.show()

# %%
# Plot ROC Curve
def plot_roc_curve(X_test, y_test, model):
    y_pred_proba = model.predict(X_test)

    # Compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(9):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred_proba[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # Plot ROC curve for each class
    plt.figure(figsize=(10, 8))
    for i in range(9):
        plt.plot(fpr[i], tpr[i], lw=2, label=f'Class {i} (AUC = {roc_auc[i]:.6f})')

    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc='lower right')
    plt.show()

# %%
import seaborn as sns

# Confusion Matrix
def plot_confusion_matrix(X_test, y_test, model):
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true = np.argmax(y_test, axis=1)

    conf_matrix = confusion_matrix(y_true, y_pred_classes)
    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=list(range(9)), yticklabels=list(range(9)))
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix')
    plt.show()

# %% [markdown]
# ## 2. CNN classifier + ROC curves + confusion matrices
#
# Steps:
# - Build a CNN classifier on the **standard** dataset (9 classes)
# - Train on train set, validate on val set
# - Plot training history (loss & accuracy)
# - Compute ROC curves (one-vs-rest) on the standard test set
# - Compute confusion matrix for standard test

# %%
from keras.src.utils import to_categorical

# Convert labels into one-hot encoding
# (used as higher dimensional encoding st. each class is linear independent)
# (Modell learns to represent new datapoints near its label representation)

y_train_enc = to_categorical(y_train_std, 9)
y_val_enc = to_categorical(y_val_std, 9)
y_test_enc = to_categorical(y_test_std, 9)

print(y_train_enc[0])
# Out:
# [0. 0. 0. 0. 0. 0. 0. 0. 1.]

# %%
# custom data augmentation layer
# used as a regularisation technique when training on rel. few data

data_augmentation = models.Sequential([
    layers.RandomRotation(0.12),
    #layers.RandomFlip("horizontal"),   # studies showed that rotation is not randomly distributed
    #layers.RandomFlip("vertical"),
    #layers.RandomZoom(0.05)    # Some Galaxies already zoomed in others tiny (could crop galaxies)
])

# %%
from sklearn.utils.class_weight import compute_class_weight

# add class weights
# some classes are less representated
# (only on train set s.t. no information about whole distribution is given to the model)

# calculation of weight
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train_std),
    y=y_train_std
)

# weight dictionary
class_weight_dict = {i: weight for i, weight in enumerate(class_weights)}

print(class_weight_dict)
# Out:
# {0: np.float64(0.9980822246194414), 1: np.float64(0.6998655236174147), 2: np.float64(0.9133486892618186), 3: np.float64(5.540252827677977), 4: np.float64(0.9061921863097181), 5: np.float64(1.0111718275652701), 6: np.float64(0.7041265009301539), 7: np.float64(1.299469413233458), 8: np.float64(0.9884852801519468)}

# %%
# CNN Classifier
classifier_input = keras.Input(shape=(64, 64, 3))

# Data augmentation for some more regularization
x = data_augmentation(classifier_input)

# first layer
x = layers.Conv2D(16, (3, 3), padding="same")(x)
x = layers.BatchNormalization()(x)  # less dead neurons and vanaishing/exploding gradients
x = layers.Activation("relu")(x)
x = layers.MaxPooling2D((2, 2))(x)  # get some stronger edges (especially for small spiral structure)
                                    # get rid of noice
# second layer
x = layers.Conv2D(32, (3, 3), padding="same")(x)
x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)
x = layers.MaxPooling2D((2, 2))(x)

# third layer
x = layers.Conv2D(64, (3, 3), padding="same")(x)
x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)      #TODO: Try ELU
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Dropout(0.25)(x)   # Get less Overfitting

# classifier layer
x = layers.Flatten()(x)
x = layers.Dense(24)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)
x = layers.Dropout(0.35)(x)   # Get less Overfitting
classifier_output = layers.Dense(9, activation="softmax")(x)  # Classification task gives last activation (prob vector)

classifier_model = keras.Model(classifier_input, classifier_output, name="classifier")

# compile the model
classifier_model.compile(optimizer="adamW",     # Added Adam with weight decay as regularization because of better generalization
                         loss="categorical_crossentropy",     # Used CCE because of categorical distribution of classes
                         metrics=["accuracy"]
                         )

# model summary
print(classifier_model.summary())
# Out:
# Model: "classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 64, 64, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 64, 64, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 64, 64, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 32, 32, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 32, 32, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 24)             │        98,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 24)             │            96 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 24)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 24)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 9)              │           225 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 122,681 (479.22 KB)
#  Trainable params: 122,409 (478.16 KB)
#  Non-trainable params: 272 (1.06 KB)
# None

# %%
# Early stopping, adaptive learning rate to avoid overfitting
callbacks = [
    keras.callbacks.ReduceLROnPlateau(monitor="val_loss",   # LR scheduler to better converge when stuck on certain niveau
                                      factor=0.6,           # more stable convergence/optimization
                                      patience=4,
                                      min_lr=1e-6,
                                      verbose=1
                                      ),
    keras.callbacks.EarlyStopping(monitor="val_loss",   # reduce training time and less overfitting
                                  patience=15,    # st. no train stop before LR schedular stablelizes val_loss
                                  restore_best_weights=True,
                                  verbose=1
                                  ),
]

# Train model
classifier_fit = classifier_model.fit(X_train_std,
                                      y_train_enc,
                                      epochs=100,
                                      batch_size=128,
                                      validation_data=(X_val_std, y_val_enc),
                                      class_weight=class_weight_dict,
                                      callbacks=callbacks
                                      )
# Out:
# Epoch 1/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 53ms/step - accuracy: 0.1812 - loss: 2.2506 - val_accuracy: 0.1587 - val_loss: 2.2786 - learning_rate: 0.0010
# Epoch 2/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.3075 - loss: 1.8135 - val_accuracy: 0.1587 - val_loss: 2.6182 - learning_rate: 0.0010
# Epoch 3/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.3690 - loss: 1.6568 - val_accuracy: 0.1587 - val_loss: 2.6031 - learning_rate: 0.0010
# Epoch 4/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.4131 - loss: 1.5333 - val_accuracy: 0.1587 - val_loss: 2.6375 - learning_rate: 0.0010
# Epoch 5/100
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.4266 - loss: 1.4610
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4270 - loss: 1.4605 - val_accuracy: 0.1787 - val_loss: 2.4212 - learning_rate: 0.0010
# Epoch 6/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.4608 - loss: 1.3624 - val_accuracy: 0.1960 - val_loss: 2.2158 - learning_rate: 6.0000e-04
# Epoch 7/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.4897 - loss: 1.3310 - val_accuracy: 0.3194 - val_loss: 1.7827 - learning_rate: 6.0000e-04
# Epoch 8/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.4892 - loss: 1.2985 - val_accuracy: 0.3751 - val_loss: 1.5819 - learning_rate: 6.0000e-04
# Epoch 9/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.4949 - loss: 1.2860 - val_accuracy: 0.4659 - val_loss: 1.3675 - learning_rate: 6.0000e-04
# Epoch 10/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.5028 - loss: 1.2603 - val_accuracy: 0.5180 - val_loss: 1.2581 - learning_rate: 6.0000e-04
# Epoch 11/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.5322 - loss: 1.2189 - val_accuracy: 0.5442 - val_loss: 1.1941 - learning_rate: 6.0000e-04
# Epoch 12/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5338 - loss: 1.1813 - val_accuracy: 0.5552 - val_loss: 1.1903 - learning_rate: 6.0000e-04
# Epoch 13/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5306 - loss: 1.1882 - val_accuracy: 0.5572 - val_loss: 1.2267 - learning_rate: 6.0000e-04
# Epoch 14/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5703 - loss: 1.1284 - val_accuracy: 0.5286 - val_loss: 1.2564 - learning_rate: 6.0000e-04
# Epoch 15/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.5649 - loss: 1.1218 - val_accuracy: 0.5617 - val_loss: 1.1773 - learning_rate: 6.0000e-04
# Epoch 16/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.5842 - loss: 1.1126 - val_accuracy: 0.5584 - val_loss: 1.2009 - learning_rate: 6.0000e-04
# Epoch 17/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.5884 - loss: 1.0858 - val_accuracy: 0.6172 - val_loss: 1.0270 - learning_rate: 6.0000e-04
# Epoch 18/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5832 - loss: 1.0866 - val_accuracy: 0.5961 - val_loss: 1.1490 - learning_rate: 6.0000e-04
# Epoch 19/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5895 - loss: 1.0783 - val_accuracy: 0.6263 - val_loss: 1.0176 - learning_rate: 6.0000e-04
# Epoch 20/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.5903 - loss: 1.0847 - val_accuracy: 0.6734 - val_loss: 0.9355 - learning_rate: 6.0000e-04
# Epoch 21/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.6055 - loss: 1.0295 - val_accuracy: 0.6402 - val_loss: 1.0265 - learning_rate: 6.0000e-04
# Epoch 22/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.6118 - loss: 1.0153 - val_accuracy: 0.6107 - val_loss: 1.0309 - learning_rate: 6.0000e-04
# Epoch 23/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6119 - loss: 1.0127 - val_accuracy: 0.5915 - val_loss: 1.0904 - learning_rate: 6.0000e-04
# Epoch 24/100
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6314 - loss: 0.9790
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6312 - loss: 0.9793 - val_accuracy: 0.6172 - val_loss: 1.0277 - learning_rate: 6.0000e-04
# Epoch 25/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6264 - loss: 0.9940 - val_accuracy: 0.5682 - val_loss: 1.2303 - learning_rate: 3.6000e-04
# Epoch 26/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.6429 - loss: 0.9587 - val_accuracy: 0.7065 - val_loss: 0.8733 - learning_rate: 3.6000e-04
# Epoch 27/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.6186 - loss: 1.0031 - val_accuracy: 0.6914 - val_loss: 0.8992 - learning_rate: 3.6000e-04
# Epoch 28/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.6164 - loss: 1.0079 - val_accuracy: 0.6811 - val_loss: 0.9050 - learning_rate: 3.6000e-04
# Epoch 29/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.6453 - loss: 0.9269 - val_accuracy: 0.7111 - val_loss: 0.8401 - learning_rate: 3.6000e-04
# Epoch 30/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6506 - loss: 0.9394 - val_accuracy: 0.7135 - val_loss: 0.8411 - learning_rate: 3.6000e-04
# Epoch 31/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6615 - loss: 0.9083 - val_accuracy: 0.7130 - val_loss: 0.8247 - learning_rate: 3.6000e-04
# Epoch 32/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.6547 - loss: 0.9108 - val_accuracy: 0.7154 - val_loss: 0.8521 - learning_rate: 3.6000e-04
# Epoch 33/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.6528 - loss: 0.9062 - val_accuracy: 0.6410 - val_loss: 1.0413 - learning_rate: 3.6000e-04
# Epoch 34/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6611 - loss: 0.8903 - val_accuracy: 0.6402 - val_loss: 0.9866 - learning_rate: 3.6000e-04
# Epoch 35/100
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6620 - loss: 0.8929
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.6619 - loss: 0.8929 - val_accuracy: 0.7070 - val_loss: 0.8534 - learning_rate: 3.6000e-04
# Epoch 36/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.6680 - loss: 0.8747 - val_accuracy: 0.7063 - val_loss: 0.8368 - learning_rate: 2.1600e-04
# Epoch 37/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.6390 - loss: 0.9364 - val_accuracy: 0.7092 - val_loss: 0.8129 - learning_rate: 2.1600e-04
# Epoch 38/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6721 - loss: 0.8763 - val_accuracy: 0.6984 - val_loss: 0.8481 - learning_rate: 2.1600e-04
# Epoch 39/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6752 - loss: 0.8738 - val_accuracy: 0.7017 - val_loss: 0.8672 - learning_rate: 2.1600e-04
# Epoch 40/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6547 - loss: 0.8731 - val_accuracy: 0.7169 - val_loss: 0.8242 - learning_rate: 2.1600e-04
# Epoch 41/100
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6666 - loss: 0.8900
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.00012960000021848827.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.6667 - loss: 0.8896 - val_accuracy: 0.6892 - val_loss: 0.8784 - learning_rate: 2.1600e-04
# Epoch 42/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.6770 - loss: 0.8501 - val_accuracy: 0.7231 - val_loss: 0.7828 - learning_rate: 1.2960e-04
# Epoch 43/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6716 - loss: 0.8359 - val_accuracy: 0.7387 - val_loss: 0.7577 - learning_rate: 1.2960e-04
# Epoch 44/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.6755 - loss: 0.8551 - val_accuracy: 0.7392 - val_loss: 0.7585 - learning_rate: 1.2960e-04
# Epoch 45/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.6936 - loss: 0.8188 - val_accuracy: 0.7440 - val_loss: 0.7484 - learning_rate: 1.2960e-04
# Epoch 46/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.6761 - loss: 0.8314 - val_accuracy: 0.7469 - val_loss: 0.7541 - learning_rate: 1.2960e-04
# Epoch 47/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6912 - loss: 0.8238 - val_accuracy: 0.7241 - val_loss: 0.7999 - learning_rate: 1.2960e-04
# Epoch 48/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6784 - loss: 0.8488 - val_accuracy: 0.7442 - val_loss: 0.7450 - learning_rate: 1.2960e-04
# Epoch 49/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6827 - loss: 0.8277 - val_accuracy: 0.7409 - val_loss: 0.7552 - learning_rate: 1.2960e-04
# Epoch 50/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7049 - loss: 0.8052 - val_accuracy: 0.7109 - val_loss: 0.8307 - learning_rate: 1.2960e-04
# Epoch 51/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.6849 - loss: 0.8112 - val_accuracy: 0.7157 - val_loss: 0.8231 - learning_rate: 1.2960e-04
# Epoch 52/100
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6952 - loss: 0.8109
# Epoch 52: ReduceLROnPlateau reducing learning rate to 7.775999838486313e-05.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.6950 - loss: 0.8112 - val_accuracy: 0.7322 - val_loss: 0.7801 - learning_rate: 1.2960e-04
# Epoch 53/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6910 - loss: 0.8154 - val_accuracy: 0.7433 - val_loss: 0.7523 - learning_rate: 7.7760e-05
# Epoch 54/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6948 - loss: 0.7956 - val_accuracy: 0.7495 - val_loss: 0.7361 - learning_rate: 7.7760e-05
# Epoch 55/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6938 - loss: 0.8026 - val_accuracy: 0.7267 - val_loss: 0.7889 - learning_rate: 7.7760e-05
# Epoch 56/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.6878 - loss: 0.8299 - val_accuracy: 0.7358 - val_loss: 0.7589 - learning_rate: 7.7760e-05
# Epoch 57/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.6983 - loss: 0.7993 - val_accuracy: 0.7250 - val_loss: 0.7966 - learning_rate: 7.7760e-05
# Epoch 58/100
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6992 - loss: 0.8040
# Epoch 58: ReduceLROnPlateau reducing learning rate to 4.6655999904032795e-05.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.6990 - loss: 0.8041 - val_accuracy: 0.7411 - val_loss: 0.7496 - learning_rate: 7.7760e-05
# Epoch 59/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6998 - loss: 0.7767 - val_accuracy: 0.7534 - val_loss: 0.7272 - learning_rate: 4.6656e-05
# Epoch 60/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.6810 - loss: 0.8321 - val_accuracy: 0.7500 - val_loss: 0.7305 - learning_rate: 4.6656e-05
# Epoch 61/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.6932 - loss: 0.8020 - val_accuracy: 0.7452 - val_loss: 0.7375 - learning_rate: 4.6656e-05
# Epoch 62/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6912 - loss: 0.8191 - val_accuracy: 0.7507 - val_loss: 0.7246 - learning_rate: 4.6656e-05
# Epoch 63/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6922 - loss: 0.8004 - val_accuracy: 0.7488 - val_loss: 0.7370 - learning_rate: 4.6656e-05
# Epoch 64/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.6879 - loss: 0.8095 - val_accuracy: 0.7555 - val_loss: 0.7203 - learning_rate: 4.6656e-05
# Epoch 65/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.6905 - loss: 0.8147 - val_accuracy: 0.7512 - val_loss: 0.7311 - learning_rate: 4.6656e-05
# Epoch 66/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6856 - loss: 0.8231 - val_accuracy: 0.7430 - val_loss: 0.7474 - learning_rate: 4.6656e-05
# Epoch 67/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6944 - loss: 0.7797 - val_accuracy: 0.7536 - val_loss: 0.7297 - learning_rate: 4.6656e-05
# Epoch 68/100
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7060 - loss: 0.8006
# Epoch 68: ReduceLROnPlateau reducing learning rate to 2.799360081553459e-05.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7057 - loss: 0.8008 - val_accuracy: 0.7474 - val_loss: 0.7391 - learning_rate: 4.6656e-05
# Epoch 69/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.6918 - loss: 0.8180 - val_accuracy: 0.7502 - val_loss: 0.7405 - learning_rate: 2.7994e-05
# Epoch 70/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.6923 - loss: 0.7931 - val_accuracy: 0.7538 - val_loss: 0.7234 - learning_rate: 2.7994e-05
# Epoch 71/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.6915 - loss: 0.8224 - val_accuracy: 0.7481 - val_loss: 0.7334 - learning_rate: 2.7994e-05
# Epoch 72/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7152 - loss: 0.7850 - val_accuracy: 0.7562 - val_loss: 0.7146 - learning_rate: 2.7994e-05
# Epoch 73/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6949 - loss: 0.8043 - val_accuracy: 0.7524 - val_loss: 0.7227 - learning_rate: 2.7994e-05
# Epoch 74/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.7045 - loss: 0.7828 - val_accuracy: 0.7538 - val_loss: 0.7216 - learning_rate: 2.7994e-05
# Epoch 75/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.6805 - loss: 0.8073 - val_accuracy: 0.7481 - val_loss: 0.7298 - learning_rate: 2.7994e-05
# Epoch 76/100
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6937 - loss: 0.8015
# Epoch 76: ReduceLROnPlateau reducing learning rate to 1.6796160707599483e-05.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6937 - loss: 0.8014 - val_accuracy: 0.7558 - val_loss: 0.7193 - learning_rate: 2.7994e-05
# Epoch 77/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7007 - loss: 0.7890 - val_accuracy: 0.7512 - val_loss: 0.7260 - learning_rate: 1.6796e-05
# Epoch 78/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.6900 - loss: 0.8027 - val_accuracy: 0.7565 - val_loss: 0.7157 - learning_rate: 1.6796e-05
# Epoch 79/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.7099 - loss: 0.7739 - val_accuracy: 0.7531 - val_loss: 0.7182 - learning_rate: 1.6796e-05
# Epoch 80/100
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7104 - loss: 0.7786
# Epoch 80: ReduceLROnPlateau reducing learning rate to 1.007769642455969e-05.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7102 - loss: 0.7787 - val_accuracy: 0.7510 - val_loss: 0.7241 - learning_rate: 1.6796e-05
# Epoch 81/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6966 - loss: 0.8154 - val_accuracy: 0.7548 - val_loss: 0.7188 - learning_rate: 1.0078e-05
# Epoch 82/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.6891 - loss: 0.8089 - val_accuracy: 0.7567 - val_loss: 0.7220 - learning_rate: 1.0078e-05
# Epoch 83/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.6996 - loss: 0.7892 - val_accuracy: 0.7524 - val_loss: 0.7254 - learning_rate: 1.0078e-05
# Epoch 84/100
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6927 - loss: 0.7808
# Epoch 84: ReduceLROnPlateau reducing learning rate to 6.046617636457085e-06.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6928 - loss: 0.7812 - val_accuracy: 0.7558 - val_loss: 0.7223 - learning_rate: 1.0078e-05
# Epoch 85/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7105 - loss: 0.7687 - val_accuracy: 0.7570 - val_loss: 0.7178 - learning_rate: 6.0466e-06
# Epoch 86/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7009 - loss: 0.7838 - val_accuracy: 0.7553 - val_loss: 0.7181 - learning_rate: 6.0466e-06
# Epoch 87/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7085 - loss: 0.7664 - val_accuracy: 0.7534 - val_loss: 0.7193 - learning_rate: 6.0466e-06
# Epoch 87: early stopping
# Restoring model weights from the end of the best epoch: 72.

# %%
# Evaluate test set
test_loss, test_acc = classifier_model.evaluate(X_test_std, y_test_enc)
print(f"Test accuracy: {test_acc:.5f}")   # most of time between 74-80%
# Out:
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7409 - loss: 0.7506
# Test accuracy: 0.74712

# %%
# accuracy is lower then expected if compared with ROC-Curve
# reasons: Class imbalance (argmax preferse bigger classes) and argmax vs threshhold

# %%
plot_training_history(classifier_fit)

# %%
plot_roc_curve(X_test_std, y_test_enc, classifier_model)
# Out:
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
plot_confusion_matrix(X_test_std, y_test_enc, classifier_model)
# Out:
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# 0=Merging: missclassification most likely because of many different shapes
# 6=unbarred loose: missclassification most likely because of simalar color like barred (5) und not loose ones (4)
#                   sometimes shapes are evry simillar (hard to distiguisch)
# 8=edge on buldge: sometimes buldge hard to see
